# %% [markdown]
# <a href="https://colab.research.google.com/github/basecampkeple/aabsuu/blob/main/1T3LDayys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title **ONE PIECE**
#@markdown 
# !setterm -foreground red
# !nvidia-smi -L
! nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-4da30ce8-0491-c6f7-cb00-244c4930773e)
# Sun Jan 16 16:22:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#@title **UPDATE ONE PIECE LIVE**
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended texlive-science tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [867 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# ...

# %%
#@title **ONE PIECE GOD**
# !setterm -foreground red
from manim import *
# Out:
# Manim Community v0.14.0

# %%
#@title **ONE PIECE CIRCLE**
# %%manim SquareToCircle
config.media_width = "80%"
class SquareToCircle(Scene):
    def construct(self):
        circle = Circle()
        circle.set_fill(PINK, opacity=0.5)
        self.play(Create(circle))
# Out:
# [01/16/22 16:25:58] INFO     Animation 0 : Partial movie file        ]8;id=213046;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=42366;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py#516\516]8;;\
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/SquareTo
#                              Circle/2724823860_3886669728_3768686611
#                              .mp4'
#                     INFO     Combining to Movie file.                ]8;id=294451;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=801239;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py#608\608]8;;\
# ...

# %%
#@title **VPS SSH**
#@markdown https://dashboard.ngrok.com/auth

# %%
#@markdown

# %%
#@markdown 
! pip install colab_ssh --upgrade &> /dev/null

Ngrok = True 

import time, sys, os
Token = "1xqj45lSwPjdZ3fwgsilrTVs4xa_4K4kA7Y48WRsvKJrryAGm" #@param {type:'string'}
User = "root" #@param {type:'string'}
Senha = "root" #@param {type:'string'}

print('\u001b[32;1m$$\       $$$$$$\  $$\   $$\   $$\         $$$$$$$\   $$$$$$\ $$$$$$$$\ ')
print('\u001b[32;1m$$ |     $$$ __$$\ $$ | $$  |$$$$ |        $$  __$$\ $$$ __$$\\__ $$ __|')
print('\u001b[32;1m$$ |     $$$$\ $$ |$$ |$$  / \_$$ |        $$ |  $$ |$$$$\ $$ |  $$ |   ')
print('\u001b[32;1m$$ |     $$\$$\$$ |$$$$$  /    $$ |        $$$$$$$\ |$$\$$\$$ |  $$ |   ')
print('\u001b[32;1m$$ |     $$ \$$$$ |$$  $$<     $$ |        $$  __$$\ $$ \$$$$ |  $$ |   ')
print('\u001b[32;1m$$ |     $$ |\$$$ |$$ |\$$\    $$ |        $$ |  $$ |$$ |\$$$ |  $$ |   ')
print('\u001b[32;1m$$$$$$$$\\$$$$$$   /$$ | \$$\ $$$$$$\       $$$$$$$  |\$$$$$$ /   $$ |   ')
print('\u001b[32;1m\________|\______/ \__|  \__|\______|      \_______/  \______/   \__|   ')
for i in range(101):
    time.sleep(0.1)
    sys.stdout.write("\rCarregando script: %d%%" % i)
    while (i > 101):
        os.system('cls')
    sys.stdout.flush()
print('')    
def runNGROK():
    from colab_ssh import launch_ssh
    from IPython.display import clear_output
    launch_ssh(Token, password)
    clear_output()

    print("ssh", username, end='@')
    ! curl -s http://localhost:4040/api/tunnels | python3 -c \
            "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'][6:].replace(':', ' -p '))"

try:
    if username:
        username=User
        password= Senha
        pass
    elif password:
        username=User
        password= Senha
        pass
except NameError:
    username= User
    password= Senha
    


if Ngrok:
    if Token == "":
        print("Você não copiou o token do Ngrok, por favor copie o token e execute o processo novamente!")
    else:
        runNGROK()
        print("\nSeu usuario:", username, " Sua senha:", password)
# Out:
# ssh root@8.tcp.ngrok.io -p 15281
#
# Seu usuario: root  Sua senha: root

# %%
#@title **ONE PIECE LIVE ACTION**
# !setterm -foreground red

alive = True #@param {type:'boolean'}
 
! sleep 999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999
